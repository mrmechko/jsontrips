# %%
(load "lisp/genlexicon")
# Out:
# To load "jonathan":
#   Load 1 ASDF system:
#     jonathan
# ; Loading "jonathan"
# ..
# ;;;;; loading #P"/home/vagrant/shared/step/TRIPS/config/lisp/../../../src/config/lisp/unix/pathname.lisp"
# ;;;;; loading #P"/home/vagrant/shared/step/TRIPS/config/lisp/../../../src/config/lisp/sbcl/extensions.lisp"
# ;;;;; loading #P"/home/vagrant/shared/step/TRIPS/config/lisp/../../../src/config/lisp/defsystem/defsystem.lisp"
# ;;;;;; loading #P"/home/vagrant/shared/step/TRIPS/config/lisp/../../../src/config/lisp/defsystem/defsystem-3.6i/defsystem.fasl"
# ;;;; loading #P"/home/vagrant/shared/step/TRIPS/config/lisp/../../../src/LexiconManager/defsys.lisp"
# ;;;;; loading #P"/home/vagrant/shared/step/TRIPS/config/lisp/../../../src/Comm/defsys.lisp"
# ;;;;; loading #P"/home/vagrant/shared/step/TRIPS/config/lisp/../../../src/Logging/defsys.lisp"
# ;;;;; loading #P"/home/vagrant/shared/step/TRIPS/config/lisp/../../../src/util/defsys.lisp"
# ...

# %%
(in-package :lxm)
(ql:quickload :alexandria)
# Out:
# To load "alexandria":
#   Load 1 ASDF system:
#     alexandria
# ; Loading "alexandria"
# (:ALEXANDRIA)

# %%
(defparameter test (lexicon-db-word-table *lexicon-data*))
# Out:
# TEST

# %%
(alexandria:hash-table-keys TEST)
# Out:
# (W::ZWIEBACK W::ZULU W::ZUCCHINIS W::ZUCCHINI W::ZOOMED W::ZOOMING W::ZOOM
#  W::ZOOMS W::ZONKED W::ZONKING W::ZONKS W::ZONK W::ZONES W::ZONE W::ZIPCODES
#  W::ZIPCODE W::ZIP W::ZIGZAGGED W::ZIGZAGGING W::ZIGZAGS W::ZIGZAG W::ZETA
#  W::ZESTIEST W::ZESTIER W::ZESTY W::ZESTILY W::ZEROED W::ZEROING W::ZEROS
#  W::ZERO W::Z W::YUP W::YOUTHS W::YOUTH W::YOURSELVES W::YOURSELF W::YOURS
#  W::YOUR W::YOUNGEST W::YOUNGER W::YOUNG W::YOU W::YOKANS W::YOKAN W::YOGURTS
#  W::YOGURT W::YOGAS W::YOGA W::YO W::YIELDED W::YIELDING W::YIELD W::YIELDS
#  W::YET W::YESTERDAYS W::YESTERDAY W::YES W::YEP W::YELLOWTAILS W::YELLOWTAIL
#  W::YELLOWFIN W::YELLOWEST W::YELLOWER W::YELLOW W::YELLED W::YELLING W::YELLS
#  W::YELL W::YEAST W::YEARLY W::YEARS W::YEAR W::YEAH W::YAWNED W::YAWNING
#  W::YAWNS W::YAWN W::YAUTIA W::YARDLONG W::YDS W::YD W::YARDS W::YARD W::YANKEE
#  W::YANKED W::YANKING W::YANKS W::YANK W::YAMS W::YAM W::YAKKED W::YAKKING
# ...

# %%
(gethash 'W::ZUCCHINI test)
# Out:
# ((:SING W::ZUCCHINI33465
#   #S(VOCABULARY-ENTRY
#      :NAME W::ZUCCHINI33464
#      :PARTICLE NIL
#      :REMAINING-WORDS NIL
#      :WORD W::ZUCCHINI
#      :POS W::N
#      :PRONUNCIATION NIL
#      :WFEATS NIL
#      :SENSES (#S(SENSE-DEFINITION
#                  :POS W::N
#                  :LF NIL
#                  :SEM NIL
#                  :PREF 0.99
#                  :NONHIERARCHY-LF NIL
#                  :SYNTAX NIL
#                  :BOOST-WORD NIL
#                  :META-DATA NIL
#                  :PROTOTYPICAL-WORD NIL
#                  :LF-PARENT ONT::VEGETABLE
#                  :LF-FORM W::ZUCCHINI
#                  :TEMPL COUNT-PRED-TEMPL
#                  :PARAMS NIL))
#      :BOOST-WORD NIL
#      :ABBREV NIL)))

# %%
(defparameter lf (lexicon-db-lf-table *lexicon-data*))
# Out:
# LF

# %%
(alexandria:hash-table-keys lf)
# Out:
# (ONT::ZIPCODE ONT::YOUNG-VAL ONT::YOGURT ONT::YESTERDAY ONT::YELLOW ONT::YEAR
#  ONT::YEAR-DURATION ONT::VERB ONT::EVOKE-WORRY ONT::WORK ONT::UNSTEADY-MOVE
#  ONT::WITHOUT ONT::TIME-CULMINATION-REL ONT::TIME-DEADLINE-REL ONT::DEHYDRATE
#  ONT::WITH-INSTRUMENT ONT::ACCOMPANIMENT ONT::WISE-VAL ONT::WINTER
#  ONT::WIN-COMPETE ONT::WILDTYPE-OBJ ONT::WILD-VAL ONT::WIDTH-SCALE ONT::WIDEN
#  ONT::OFFENSIVE-VAL ONT::WIRELESS ONT::REASON-FOR ONT::WHITE ONT::WHEREBY
#  ONT::WET-VAL ONT::WEST ONT::WEST-RELN ONT::WELCOME ONT::MEASURE ONT::WEEK
#  ONT::WEEK-DURATION ONT::WEATHER ONT::WEAR ONT::WEAKNESS-SCALE ONT::WATER
#  ONT::STORAGE-FACILITY ONT::WALKING ONT::AWAKE ONT::WAIT-WATCH ONT::VOMIT
#  ONT::WILLING ONT::VOLUME-SCALE ONT::VOLTAGE-SCALE ONT::SENSORY-MODE-VAL
#  ONT::VISIBILITY-VAL ONT::VISIBILITY-SCALE ONT::HARMFUL-AGENCY
#  ONT::AGGRESSIVENESS-SCALE ONT::VERIFIED-VAL ONT::VERIFIABLE-VAL
#  ONT::WORTHY-VAL ONT::UTILITY-SCALE ONT::USER ONT::HABITUATED-VAL ONT::HABITUAL
# ...

# %%
(gethash 'ont::young-val lf)
# Out:
# (W::ADJ)
